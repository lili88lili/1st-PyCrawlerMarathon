# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
'''
Your Code
'''
# Out:
# '\nYour Code\n'

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
'''
Your Code
'''
# Out:
# '\nYour Code\n'

# %%
import requests
import json

r = requests.get('https://cat-fact.herokuapp.com/facts')
r.text
# Out:
# '{"all":[{"_id":"5b4911940508220014ccfe94","text":"By the time a cat is 9 years old, it will only have been awake for three years of its life.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"58e008b80aac31001185ed0d","text":"Adult cats only meow to communicate with humans.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e009650aac31001185ed13","text":"In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00b2b0aac31001185ed1f","text":"A cat has five toes on his front paws, and four on the back, unless he\'s a polydactyl.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00be30aac31001185edfe","text":"Cats use their whiskers to detect if they can fit through a space.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00b4d0aac31001185ed22","text":"Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"5b199196ce456e001424256a","text":"Cats can distinguish different flavors in water.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b1b411d841d9700146158d9","text":"The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b4912c60508220014ccfe99","text":"Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"58e007db0aac31001185ecf7","text":"There are cats who have survived falls from over 32 stories (320 meters) onto concrete.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e008800aac31001185ed07","text":"Wikipedia has a recording of a cat meowing, because why not?","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e009790aac31001185ed14","text":"The technical term for \\"hairball\\" is \\"bezoar.\\"","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e00a120aac31001185ed17","text":"A cat\'s brain is 90% similar to a human\'s — more similar than to a dog\'s.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"591d9b2f227c1a0020d26823","text":"Every year, nearly four million cats are eaten in China as a delicacy.","type":"cat","user":{"_id":"587288f6e6f85e64ae1c7ef7","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":3,"userUpvoted":null},{"_id":"5974fb4dfedacb0020b5b4cc","text":"Cats can survive falls from up to 65 feet or more.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":3,"userUpvoted":null},{"_id":"59a60ba66acf530020f35873","te ...

# %%
import requests
import json

r2 = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
r2.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 100,\n"value": [{"StationIdentifier": "2560H019","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 4.45},{"StationIdentifier": "2370H024","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 195.41},{"StationIdentifier": "1630H033","RecordTime": "Dec 4, 2019 7:20:00 AM","WaterLevel": 0.07},{"StationIdentifier": "2560H006","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 3.03},{"StationIdentifier": "2420H046","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 35.93},{"StationIdentifier": "1630H029","RecordTime": "Dec 4, 2019 7:20:00 AM","WaterLevel": 4.97},{"StationIdentifier": "2420H037","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 133.39},{"StationIdentifier": "1680H004","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 1.1},{"StationIdentifier": "1630H028","RecordTime": "Dec 4, 2019 7:20:00 AM","WaterLevel": 10.23},{"StationIdentifier": "1730H074","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 245.48},{"StationIdentifier": "2420H018","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 156.18},{"StationIdentifier": "1630H035","RecordTime": "Dec 4, 2019 7:20:00 AM","WaterLevel": 402.47},{"StationIdentifier": "1630H025","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 1.42},{"StationIdentifier": "1730H069","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 140.74},{"StationIdentifier": "2370H018","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 124.11},{"StationIdentifier": "1430H052","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 173.07},{"StationIdentifier": "1730H062","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 41.74},{"StationIdentifier": "1740H009","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 32.37},{"StationIdentifier": "1630H026","RecordTime": "Dec 4, 2019 7:20:00 AM","WaterLevel": 44.48},{"StationIdentifier": "1730H065","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 90.69},{"StationIdentifier": "2200H011","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 25.7},{"StationIdentifier": "1430H032","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 337.56},{"StationIdentifier": "1670H003","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 0.21},{"StationIdentifier": "1730H071","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 35.32},{"StationIdentifier": "2200H028","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 277.75},{"StationIdentifier": "1510H063","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 263.83},{"StationIdentifier": "1730H058","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 113.58},{"StationIdentifier": "1630H031","RecordTime": "Dec 4, 2019 7:20:00 AM","WaterLevel": 0.47},{"StationIdentifier": "1430H029","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 50.62},{"StationIdentifier": "1510H081","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 229.09},{"StationIdentifier": "1730H067","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": -999998},{"StationIdentifier": "2200H021","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 369.58},{"StationIdentifier": "1430H057","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 31.69},{"StationIdentifier": "1730H045","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 5.1},{"StationIdentifier": "1630H020","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 35.28},{"StationIdentifier": "1430H025","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 9.93},{"StationIdentifier": "1510H057","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 88.47},{"StationIdentifier": "1430H053","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 38.45},{"StationIdentifier": "1540H031","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 10.09},{"StationIdentifier": "1550H016","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 12.24},{"StationIdentifier": "1740H007","RecordTime": "Dec 4, 2019 7:40:00 AM","WaterLevel": 0.81},{"StationIdentifier": "1590H019","RecordTime": "Dec 4, 2019 7:40:00 AM"," ...

# %%
import json
print(type(json.loads(r.text)))
json.loads(r.text)
# Out:
# <class 'dict'>
# {'all': [{'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c470572a99c3f00140fe4bd',
#    'text': 'Cats like being brushed by their owners, because it reminds them of their mother.',
#    'type': 'cat',
#    'user': {'_id': '5c470492a99c3f00140fe4bc',
#     'name': {'first': 'David', 'last': 'Gippner'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
# ...
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de0a5d32abaa900154956c9',
#    'type': 'cat',
#    'text': 'This is the first time.',
#    'user': {'_id': '5de0a5b02abaa900154956c8',
#     'name': {'first': 'Sushen', 'last': 'Biswas'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de608922c455b00153df05d',
#    'type': 'cat',
#    'text': 'Coba cat nyata.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de6090e2c455b00153df05e',
#    'type': 'cat',
#    'text': 'Cats has no hands.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de609812c455b00153df05f',
#    'type': 'cat',
#    'text': 'Testing aja.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
import json
print(type(r2.text))
print(type(json.loads(r2.text)))
json.loads(r2.text)
# Out:
# <class 'str'>
# <class 'dict'>
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'StationIdentifier': '2560H019',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 4.45},
#   {'StationIdentifier': '2370H024',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 195.41},
#   {'StationIdentifier': '1630H033',
#    'RecordTime': 'Dec 4, 2019 7:20:00 AM',
#    'WaterLevel': 0.07},
#   {'StationIdentifier': '2560H006',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 3.03},
#   {'StationIdentifier': '2420H046',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 35.93},
#   {'StationIdentifier': '1630H029',
#    'RecordTime': 'Dec 4, 2019 7:20:00 AM',
#    'WaterLevel': 4.97},
#   {'StationIdentifier': '2420H037',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 133.39},
#   {'StationIdentifier': '1680H004',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 1.1},
#   {'StationIdentifier': '1630H028',
#    'RecordTime': 'Dec 4, 2019 7:20:00 AM',
#    'WaterLevel': 10.23},
#   {'StationIdentifier': '1730H074',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 245.48},
#   {'StationIdentifier': '2420H018',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 156.18},
#   {'StationIdentifier': '1630H035',
#    'RecordTime': 'Dec 4, 2019 7:20:00 AM',
#    'WaterLevel': 402.47},
#   {'StationIdentifier': '1630H025',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 1.42},
#   {'StationIdentifier': '1730H069',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 140.74},
#   {'StationIdentifier': '2370H018',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 124.11},
#   {'StationIdentifier': '1430H052',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 173.07},
#   {'StationIdentifier': '1730H062',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 41.74},
#   {'StationIdentifier': '1740H009',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 32.37},
#   {'StationIdentifier': '1630H026',
#    'RecordTime': 'Dec 4, 2019 7:20:00 AM',
#    'WaterLevel': 44.48},
#   {'StationIdentifier': '1730H065',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 90.69},
#   {'StationIdentifier': '2200H011',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 25.7},
#   {'StationIdentifier': '1430H032',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 337.56},
#   {'StationIdentifier': '1670H003',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 0.21},
#   {'StationIdentifier': '1730H071',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 35.32},
#   {'StationIdentifier': '2200H028',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 277.75},
#   {'StationIdentifier': '1510H063',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 263.83},
#   {'StationIdentifier': '1730H058',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 113.58},
#   {'StationIdentifier': '1630H031',
#    'RecordTime': 'Dec 4, 2019 7:20:00 AM',
#    'WaterLevel': 0.47},
#   {'StationIdentifier': '1430H029',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 50.62},
#   {'StationIdentifier': '1510H081',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 229.09},
#   {'StationIdentifier': '1730H067',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': -999998},
#   {'StationIdentifier': '2200H021',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 369.58},
#   {'StationIdentifier': '1430H057',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 31.69},
#   {'StationIdentifier': '1730H045',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 5.1},
#   {'StationIdentifier': '1630H020',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 35.28},
#   {'StationIdentifier': '1430H025',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 9.93},
#   {'StationIdentifier': '1510H057',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 88.47},
#   {'StationIdentifier': '1430H053',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 38.45},
#   {'StationIdentifier': '1540H031',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 10.09},
#   {'StationIdentifier': '1550H016',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 12.24},
#   {'StationIdentifier': '1740H007',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 0.81},
#   {'StationIdentifier': '1590H019',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 14.88},
#   {'StationIdentifier': '1540H038',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 54.79},
#   {'StationIdentifier': '1510H049',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 470.82},
#   {'StationIdentifier': '1430H048',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 166.01},
#   {'StationIdentifier': '1540H014',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 7.96},
#   {'StationIdentifier': '1430H060',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 20.05},
#   {'StationIdentifier': '1630H013',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 15.52},
#   {'StationIdentifier': '1430H038',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 74.78},
#   {'StationIdentifier': '1540H035',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 86.79},
#   {'StationIdentifier': '1420H056',
#    'RecordTime': 'Dec 3, 2019 6:50:00 PM',
#    'WaterLevel': 196.52},
#   {'StationIdentifier': '1430H046',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 111.08},
#   {'StationIdentifier': '1510H087',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 428.67},
#   {'StationIdentifier': '1430H055',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 78.58},
#   {'StationIdentifier': '1540H036',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 0.22},
#   {'StationIdentifier': '1510H083',
#    'RecordTime': 'Dec 4, 2019 7:30:00 AM',
#    'WaterLevel': 116.62},
#   {'StationIdentifier': '1510H088',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 141.08},
#   {'StationIdentifier': '1140H126',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 80.96},
#   {'StationIdentifier': '1420H053',
#    'RecordTime': 'Dec 4, 2019 7:30:00 AM',
#    'WaterLevel': 471.55},
#   {'StationIdentifier': '1300H024',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 28.84},
#   {'StationIdentifier': '1420H052',
#    'RecordTime': 'Dec 4, 2019 7:30:00 AM',
#    'WaterLevel': 429.81},
#   {'StationIdentifier': '1510H076',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 4.9},
#   {'StationIdentifier': '1430H044',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 139.49},
#   {'StationIdentifier': '1510H085',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 279.77},
#   {'StationIdentifier': '1400H020',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 318.7},
#   {'StationIdentifier': '1140H095',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 109.95},
#   {'StationIdentifier': '1300H021',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': -0.58},
#   {'StationIdentifier': '1350H030',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 57.48},
#   {'StationIdentifier': '1510H064',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 265.04},
#   {'StationIdentifier': '1300H013',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 245.72},
#   {'StationIdentifier': '1400H008',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 479.64},
#   {'StationIdentifier': '1400H019',
#    'RecordTime': 'Dec 4, 2019 7:30:00 AM',
#    'WaterLevel': 310.14},
#   {'StationIdentifier': '1140H067',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 28.91},
#   {'StationIdentifier': '1290H006',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 66.94},
#   {'StationIdentifier': '1350H028',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 232.6},
#   {'StationIdentifier': '1350H019',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 33.7},
#   {'StationIdentifier': '1140H109',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 48.89},
#   {'StationIdentifier': '1350H021',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 320.17},
#   {'StationIdentifier': '1140H105',
#    'RecordTime': 'Dec 4, 2019 7:50:00 AM',
#    'WaterLevel': 0.19},
#   {'StationIdentifier': '2560H025',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 3.02},
#   {'StationIdentifier': '1270H001',
#    'RecordTime': 'Dec 4, 2019 7:50:00 AM',
#    'WaterLevel': 22.46},
#   {'StationIdentifier': '1350H026',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 30.34},
#   {'StationIdentifier': '1340H013',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 247.04},
#   {'StationIdentifier': '1400H012',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 598.86},
#   {'StationIdentifier': '1350H017',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 243.84},
#   {'StationIdentifier': '1660H013',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 0.88},
#   {'StationIdentifier': '2560H022',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 194.55},
#   {'StationIdentifier': '1660H011',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 1.48},
#   {'StationIdentifier': '1350H024',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 259.65},
#   {'StationIdentifier': '1340H010',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 0.62},
#   {'StationIdentifier': '1140H097',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 171.95},
#   {'StationIdentifier': '1340H016',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': -0.37},
#   {'StationIdentifier': '1650H011',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 0.35},
#   {'StationIdentifier': '1590H015',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 9.29},
#   {'StationIdentifier': '1660H010',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 7.45},
#   {'StationIdentifier': '1350H012',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 12.27},
#   {'StationIdentifier': '1340H009',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 175.83},
#   {'StationIdentifier': '2420H024',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 4.73},
#   {'StationIdentifier': '2370H016',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 167.78},
#   {'StationIdentifier': '1650H008',
#    'RecordTime': 'Dec 4, 2019 7:40:00 AM',
#    'WaterLevel': 0.32}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}

# %%
r3 = requests.get('https://api.github.com/events')
print(type(json.loads(r3.text)))
json.loads(r3.text)
# Out:
# <class 'list'>
# [{'id': '11004964672',
#   'type': 'CreateEvent',
#   'actor': {'id': 58493545,
#    'login': 'esblymelun',
#    'display_login': 'esblymelun',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/esblymelun',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58493545?'},
#   'repo': {'id': 225742793,
#    'name': 'esblymelun/esbly',
#    'url': 'https://api.github.com/repos/esblymelun/esbly'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'none',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-04T00:18:48Z'},
#  {'id': '11004964668',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 187620727,
#    'name': 'ErmenegildoCumbe/Biblio',
#    'url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio'},
#   'payload': {'action': 'opened',
#    'number': 2,
#    'pull_request': {'url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/pulls/2',
#     'id': 348622697,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ4NjIyNjk3',
#     'html_url': 'https://github.com/ErmenegildoCumbe/Biblio/pull/2',
#     'diff_url': 'https://github.com/ErmenegildoCumbe/Biblio/pull/2.diff',
#     'patch_url': 'https://github.com/ErmenegildoCumbe/Biblio/pull/2.patch',
#     'issue_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/issues/2',
#     'number': 2,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump symfony/http-foundation from 3.4.12 to 3.4.36',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': "Bumps [symfony/http-foundation](https://github.com/symfony/http-foundation) from 3.4.12 to 3.4.36.\n<details>\n<summary>Commits</summary>\n\n- [`d2d0cfe`](https://github.com/symfony/http-foundation/commit/d2d0cfe8e319d9df44c4cca570710fcf221d4593) [HttpFoundation] Fixed typo\n- [`f7efd0b`](https://github.com/symfony/http-foundation/commit/f7efd0b387b7bdbfe0fd1e38fe6b7d4a812b4e39) Simpler example for Apache basic auth workaround\n- [`ef5fed4`](https://github.com/symfony/http-foundation/commit/ef5fed4469fb079c0b188ab0401cd1b28752865b) [HttpFoundation] Allow redirecting to URLs that contain a semicolon\n- [`c9425ba`](https://github.com/symfony/http-foundation/commit/c9425bae96ae95449d59f8286529cf144bb228ab) Fix MySQL column type definition.\n- [`9e4b3ac`](https://github.com/symfony/http-foundation/commit/9e4b3ac8fa3348b4811674d23de32d201de225ce) [HttpFoundation] fix guessing mime-types of files with leading dash\n- [`a5d46a3`](https://github.com/symfony/http-foundation/commit/a5d46a33e8649ba802cebe520d188b04385572a2) Fix MockFileSessionStorageTest::sessionDir being used after it's unset\n- [`7b4626a`](https://github.com/symfony/http-foundation/commit/7b4626ab40d8562707e6d1c9a6fab977a86c2037) Remove unused local variables in tests\n- [`4db558c`](https://github.com/symfony/http-foundation/commit/4db558c7c6777aac02293efbfe7c7c5d4c1385c3) Add plus character `+` to legal mime subtype\n- [`233f40c`](https://github.com/symfony/http-foundation/commit/233f40cbebd595ffd91ddf291355f8a930a13777) [HttpFoundation] Check if data passed to SessionBagProxy::initialize is an array\n- [`35ffbbf`](https://github.com/symfony/http-foundation/commit/35ffbbfa73e46e28a9433692cd6c404de70e6c4c) [HttpFoundation] allow additinal characters in not raw cookies\n- Additional commits viewable in [compare view](https://github.com/symfony/http-foundation/compare/v3.4.12...v3.4.36)\n</details>\n<br />\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=symfony/http-foundation&package-manager=composer&previous-version=3.4.12&new-version=3.4.36)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don't alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot ignore this [patch|minor|major] version` will close this PR and stop Dependabot creating any more for this minor/major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://gith ...
#     'created_at': '2019-12-04T00:18:48Z',
#     'updated_at': '2019-12-04T00:18:48Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/pulls/2/commits',
#     'review_comments_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/pulls/2/comments',
#     'review_comment_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/issues/2/comments',
#     'statuses_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/statuses/2061e14d1ed63f1a970a844a3b5005c50e3fc4d7',
#     'head': {'label': 'ErmenegildoCumbe:dependabot/composer/symfony/http-foundation-3.4.36',
#      'ref': 'dependabot/composer/symfony/http-foundation-3.4.36',
#      'sha': '2061e14d1ed63f1a970a844a3b5005c50e3fc4d7',
#      'user': {'login': 'ErmenegildoCumbe',
#       'id': 32514855,
#       'node_id': 'MDQ6VXNlcjMyNTE0ODU1',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/32514855?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ErmenegildoCumbe',
#       'html_url': 'https://github.com/ErmenegildoCumbe',
#       'followers_url': 'https://api.github.com/users/ErmenegildoCumbe/followers',
#       'following_url': 'https://api.github.com/users/ErmenegildoCumbe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ErmenegildoCumbe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ErmenegildoCumbe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ErmenegildoCumbe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ErmenegildoCumbe/orgs',
#       'repos_url': 'https://api.github.com/users/ErmenegildoCumbe/repos',
#       'events_url': 'https://api.github.com/users/ErmenegildoCumbe/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ErmenegildoCumbe/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 187620727,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODc2MjA3Mjc=',
#       'name': 'Biblio',
#       'full_name': 'ErmenegildoCumbe/Biblio',
#       'private': False,
#       'owner': {'login': 'ErmenegildoCumbe',
#        'id': 32514855,
#        'node_id': 'MDQ6VXNlcjMyNTE0ODU1',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/32514855?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ErmenegildoCumbe',
#        'html_url': 'https://github.com/ErmenegildoCumbe',
#        'followers_url': 'https://api.github.com/users/ErmenegildoCumbe/followers',
#        'following_url': 'https://api.github.com/users/ErmenegildoCumbe/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ErmenegildoCumbe/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ErmenegildoCumbe/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ErmenegildoCumbe/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ErmenegildoCumbe/orgs',
#        'repos_url': 'https://api.github.com/users/ErmenegildoCumbe/repos',
#        'events_url': 'https://api.github.com/users/ErmenegildoCumbe/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ErmenegildoCumbe/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ErmenegildoCumbe/Biblio',
#       'description': 'For William',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio',
#       'forks_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/forks',
#       'keys_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/teams',
#       'hooks_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/events',
#       'assignees_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/tags',
#       'blobs_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/languages',
#       'stargazers_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/subscription',
#       'commits_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/merges',
#       'archive_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/downloads',
#       'issues_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/deployments',
#       'created_at': '2019-05-20T10:38:59Z',
#       'updated_at': '2019-05-27T08:54:11Z',
#       'pushed_at': '2019-12-04T00:18:47Z',
#       'git_url': 'git://github.com/ErmenegildoCumbe/Biblio.git',
#       'ssh_url': 'git@github.com:ErmenegildoCumbe/Biblio.git',
#       'clone_url': 'https://github.com/ErmenegildoCumbe/Biblio.git',
#       'svn_url': 'https://github.com/ErmenegildoCumbe/Biblio',
#       'homepage': None,
#       'size': 9889,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'ErmenegildoCumbe:master',
#      'ref': 'master',
#      'sha': '2d0befc37c2d5d7cb2fb6c6038e336ee57d76bf6',
#      'user': {'login': 'ErmenegildoCumbe',
#       'id': 32514855,
#       'node_id': 'MDQ6VXNlcjMyNTE0ODU1',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/32514855?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ErmenegildoCumbe',
#       'html_url': 'https://github.com/ErmenegildoCumbe',
#       'followers_url': 'https://api.github.com/users/ErmenegildoCumbe/followers',
#       'following_url': 'https://api.github.com/users/ErmenegildoCumbe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ErmenegildoCumbe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ErmenegildoCumbe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ErmenegildoCumbe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ErmenegildoCumbe/orgs',
#       'repos_url': 'https://api.github.com/users/ErmenegildoCumbe/repos',
#       'events_url': 'https://api.github.com/users/ErmenegildoCumbe/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ErmenegildoCumbe/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 187620727,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODc2MjA3Mjc=',
#       'name': 'Biblio',
#       'full_name': 'ErmenegildoCumbe/Biblio',
#       'private': False,
#       'owner': {'login': 'ErmenegildoCumbe',
#        'id': 32514855,
#        'node_id': 'MDQ6VXNlcjMyNTE0ODU1',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/32514855?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ErmenegildoCumbe',
#        'html_url': 'https://github.com/ErmenegildoCumbe',
#        'followers_url': 'https://api.github.com/users/ErmenegildoCumbe/followers',
#        'following_url': 'https://api.github.com/users/ErmenegildoCumbe/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ErmenegildoCumbe/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ErmenegildoCumbe/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ErmenegildoCumbe/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ErmenegildoCumbe/orgs',
#        'repos_url': 'https://api.github.com/users/ErmenegildoCumbe/repos',
#        'events_url': 'https://api.github.com/users/ErmenegildoCumbe/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ErmenegildoCumbe/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ErmenegildoCumbe/Biblio',
#       'description': 'For William',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio',
#       'forks_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/forks',
#       'keys_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/teams',
#       'hooks_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/events',
#       'assignees_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/tags',
#       'blobs_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/languages',
#       'stargazers_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/subscription',
#       'commits_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/merges',
#       'archive_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/downloads',
#       'issues_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/deployments',
#       'created_at': '2019-05-20T10:38:59Z',
#       'updated_at': '2019-05-27T08:54:11Z',
#       'pushed_at': '2019-12-04T00:18:47Z',
#       'git_url': 'git://github.com/ErmenegildoCumbe/Biblio.git',
#       'ssh_url': 'git@github.com:ErmenegildoCumbe/Biblio.git',
#       'clone_url': 'https://github.com/ErmenegildoCumbe/Biblio.git',
#       'svn_url': 'https://github.com/ErmenegildoCumbe/Biblio',
#       'homepage': None,
#       'size': 9889,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/pulls/2'},
#      'html': {'href': 'https://github.com/ErmenegildoCumbe/Biblio/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio/statuses/2061e14d1ed63f1a970a844a3b5005c50e3fc4d7'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 25,
#     'deletions': 24,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-12-04T00:18:48Z'},
#  {'id': '11004964654',
#   'type': 'PushEvent',
#   'actor': {'id': 57576911,
#    'login': 'cenodis',
#    'display_login': 'cenodis',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cenodis',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57576911?'},
#   'repo': {'id': 225741643,
#    'name': 'cenodis/tell',
#    'url': 'https://api.github.com/repos/cenodis/tell'},
#   'payload': {'push_id': 4351703239,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/patch-1',
#    'head': '217379465d4f34ee92204336d5e9af97919fa1ad',
#    'before': 'c1d45ae4b1a23986b4b5a294b5d0026989b2ee62',
#    'commits': [{'sha': '217379465d4f34ee92204336d5e9af97919fa1ad',
#      'author': {'email': '57576911+cenodis@users.noreply.github.com',
#       'name': 'cenodis'},
#      'message': 'Fix invalid usage message\n\nWhen mesecons is installed the invalid use message states "Invalid usage, see /help tell.". This should be "/help tellafk".',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cenodis/tell/commits/217379465d4f34ee92204336d5e9af97919fa1ad'}]},
#   'public': True,
#   'created_at': '2019-12-04T00:18:48Z'},
#  {'id': '11004964660',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 6272362,
#    'login': 'diadochos',
#    'display_login': 'diadochos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diadochos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6272362?'},
#   'repo': {'id': 74133026,
#    'name': 'diadochos/org-babel-eval-in-repl',
#    'url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl'},
#   'payload': {'action': 'closed',
#    'number': 29,
#    'pull_request': {'url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/pulls/29',
#     'id': 348349233,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ4MzQ5MjMz',
#     'html_url': 'https://github.com/diadochos/org-babel-eval-in-repl/pull/29',
#     'diff_url': 'https://github.com/diadochos/org-babel-eval-in-repl/pull/29.diff',
#     'patch_url': 'https://github.com/diadochos/org-babel-eval-in-repl/pull/29.patch',
#     'issue_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/issues/29',
#     'number': 29,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Feature/update readme',
#     'user': {'login': 'diadochos',
#      'id': 6272362,
#      'node_id': 'MDQ6VXNlcjYyNzIzNjI=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/6272362?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/diadochos',
#      'html_url': 'https://github.com/diadochos',
#      'followers_url': 'https://api.github.com/users/diadochos/followers',
#      'following_url': 'https://api.github.com/users/diadochos/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/diadochos/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/diadochos/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/diadochos/subscriptions',
#      'organizations_url': 'https://api.github.com/users/diadochos/orgs',
#      'repos_url': 'https://api.github.com/users/diadochos/repos',
#      'events_url': 'https://api.github.com/users/diadochos/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/diadochos/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "#28 \r\nSorry for the slow motion, but I added the GIF to the README.\r\nSince you've kindly provided the demo GIF, could you briefly final-check how it looks good to you @actonDev?",
#     'created_at': '2019-12-03T14:06:35Z',
#     'updated_at': '2019-12-04T00:18:48Z',
#     'closed_at': '2019-12-04T00:18:47Z',
#     'merged_at': '2019-12-04T00:18:47Z',
#     'merge_commit_sha': 'e111b4b5c6844bb389317354ea172cd96a8bb658',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/pulls/29/commits',
#     'review_comments_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/pulls/29/comments',
#     'review_comment_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/issues/29/comments',
#     'statuses_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/statuses/dcac30324d4a0fbd23799e6983050c5e8e914459',
#     'head': {'label': 'diadochos:feature/update-readme',
#      'ref': 'feature/update-readme',
#      'sha': 'dcac30324d4a0fbd23799e6983050c5e8e914459',
#      'user': {'login': 'diadochos',
#       'id': 6272362,
#       'node_id': 'MDQ6VXNlcjYyNzIzNjI=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/6272362?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/diadochos',
#       'html_url': 'https://github.com/diadochos',
#       'followers_url': 'https://api.github.com/users/diadochos/followers',
#       'following_url': 'https://api.github.com/users/diadochos/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/diadochos/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/diadochos/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/diadochos/subscriptions',
#       'organizations_url': 'https://api.github.com/users/diadochos/orgs',
#       'repos_url': 'https://api.github.com/users/diadochos/repos',
#       'events_url': 'https://api.github.com/users/diadochos/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/diadochos/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 74133026,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3NDEzMzAyNg==',
#       'name': 'org-babel-eval-in-repl',
#       'full_name': 'diadochos/org-babel-eval-in-repl',
#       'private': False,
#       'owner': {'login': 'diadochos',
#        'id': 6272362,
#        'node_id': 'MDQ6VXNlcjYyNzIzNjI=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/6272362?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/diadochos',
#        'html_url': 'https://github.com/diadochos',
#        'followers_url': 'https://api.github.com/users/diadochos/followers',
#        'following_url': 'https://api.github.com/users/diadochos/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/diadochos/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/diadochos/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/diadochos/subscriptions',
#        'organizations_url': 'https://api.github.com/users/diadochos/orgs',
#        'repos_url': 'https://api.github.com/users/diadochos/repos',
#        'events_url': 'https://api.github.com/users/diadochos/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/diadochos/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/diadochos/org-babel-eval-in-repl',
#       'description': "Send and eval org-mode babel code blocks in various REPLs (therefore it's async)",
#       'fork': False,
#       'url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl',
#       'forks_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/forks',
#       'keys_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/teams',
#       'hooks_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/hooks',
#       'issue_events_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/events',
#       'assignees_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/tags',
#       'blobs_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/languages',
#       'stargazers_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/stargazers',
#       'contributors_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/contributors',
#       'subscribers_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/subscribers',
#       'subscription_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/subscription',
#       'commits_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/merges',
#       'archive_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/downloads',
#       'issues_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/deployments',
#       'created_at': '2016-11-18T13:42:45Z',
#       'updated_at': '2019-11-10T07:09:36Z',
#       'pushed_at': '2019-12-04T00:18:47Z',
#       'git_url': 'git://github.com/diadochos/org-babel-eval-in-repl.git',
#       'ssh_url': 'git@github.com:diadochos/org-babel-eval-in-repl.git',
#       'clone_url': 'https://github.com/diadochos/org-babel-eval-in-repl.git',
#       'svn_url': 'https://github.com/diadochos/org-babel-eval-in-repl',
#       'homepage': '',
#       'size': 51,
#       'stargazers_count': 29,
#       'watchers_count': 29,
#       'language': 'Emacs Lisp',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 7,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 7,
#       'open_issues': 4,
#       'watchers': 29,
#       'default_branch': 'master'}},
#     'base': {'label': 'diadochos:master',
#      'ref': 'master',
#      'sha': '929d160685db57c4f0aedf26b52f9d7a918a40dd',
#      'user': {'login': 'diadochos',
#       'id': 6272362,
#       'node_id': 'MDQ6VXNlcjYyNzIzNjI=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/6272362?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/diadochos',
#       'html_url': 'https://github.com/diadochos',
#       'followers_url': 'https://api.github.com/users/diadochos/followers',
#       'following_url': 'https://api.github.com/users/diadochos/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/diadochos/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/diadochos/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/diadochos/subscriptions',
#       'organizations_url': 'https://api.github.com/users/diadochos/orgs',
#       'repos_url': 'https://api.github.com/users/diadochos/repos',
#       'events_url': 'https://api.github.com/users/diadochos/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/diadochos/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 74133026,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3NDEzMzAyNg==',
#       'name': 'org-babel-eval-in-repl',
#       'full_name': 'diadochos/org-babel-eval-in-repl',
#       'private': False,
#       'owner': {'login': 'diadochos',
#        'id': 6272362,
#        'node_id': 'MDQ6VXNlcjYyNzIzNjI=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/6272362?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/diadochos',
#        'html_url': 'https://github.com/diadochos',
#        'followers_url': 'https://api.github.com/users/diadochos/followers',
#        'following_url': 'https://api.github.com/users/diadochos/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/diadochos/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/diadochos/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/diadochos/subscriptions',
#        'organizations_url': 'https://api.github.com/users/diadochos/orgs',
#        'repos_url': 'https://api.github.com/users/diadochos/repos',
#        'events_url': 'https://api.github.com/users/diadochos/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/diadochos/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/diadochos/org-babel-eval-in-repl',
#       'description': "Send and eval org-mode babel code blocks in various REPLs (therefore it's async)",
#       'fork': False,
#       'url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl',
#       'forks_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/forks',
#       'keys_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/teams',
#       'hooks_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/hooks',
#       'issue_events_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/events',
#       'assignees_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/tags',
#       'blobs_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/languages',
#       'stargazers_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/stargazers',
#       'contributors_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/contributors',
#       'subscribers_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/subscribers',
#       'subscription_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/subscription',
#       'commits_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/merges',
#       'archive_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/downloads',
#       'issues_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/deployments',
#       'created_at': '2016-11-18T13:42:45Z',
#       'updated_at': '2019-11-10T07:09:36Z',
#       'pushed_at': '2019-12-04T00:18:47Z',
#       'git_url': 'git://github.com/diadochos/org-babel-eval-in-repl.git',
#       'ssh_url': 'git@github.com:diadochos/org-babel-eval-in-repl.git',
#       'clone_url': 'https://github.com/diadochos/org-babel-eval-in-repl.git',
#       'svn_url': 'https://github.com/diadochos/org-babel-eval-in-repl',
#       'homepage': '',
#       'size': 51,
#       'stargazers_count': 29,
#       'watchers_count': 29,
#       'language': 'Emacs Lisp',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 7,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 7,
#       'open_issues': 4,
#       'watchers': 29,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/pulls/29'},
#      'html': {'href': 'https://github.com/diadochos/org-babel-eval-in-repl/pull/29'},
#      'issue': {'href': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/issues/29'},
#      'comments': {'href': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/issues/29/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/pulls/29/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/pulls/29/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/diadochos/org-babel-eval-in-repl/statuses/dcac30324d4a0fbd23799e6983050c5e8e914459'}},
#     'author_association': 'OWNER',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'diadochos',
#      'id': 6272362,
#      'node_id': 'MDQ6VXNlcjYyNzIzNjI=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/6272362?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/diadochos',
#      'html_url': 'https://github.com/diadochos',
#      'followers_url': 'https://api.github.com/users/diadochos/followers',
#      'following_url': 'https://api.github.com/users/diadochos/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/diadochos/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/diadochos/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/diadochos/subscriptions',
#      'organizations_url': 'https://api.github.com/users/diadochos/orgs',
#      'repos_url': 'https://api.github.com/users/diadochos/repos',
#      'events_url': 'https://api.github.com/users/diadochos/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/diadochos/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 2,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 3,
#     'additions': 12,
#     'deletions': 5,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2019-12-04T00:18:48Z'},
#  {'id': '11004964659',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 187620727,
#    'name': 'ErmenegildoCumbe/Biblio',
#    'url': 'https://api.github.com/repos/ErmenegildoCumbe/Biblio'},
#   'payload': {'ref': 'dependabot/composer/symfony/http-foundation-3.4.36',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'For William',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-04T00:18:48Z'},
#  {'id': '11004964653',
#   'type': 'PushEvent',
#   'actor': {'id': 55067501,
#    'login': 'kucasrossy',
#    'display_login': 'kucasrossy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kucasrossy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55067501?'},
#   'repo': {'id': 223300316,
#    'name': 'kucasrossy/curso-javascript-ninja',
#    'url': 'https://api.github.com/repos/kucasrossy/curso-javascript-ninja'},
#   'payload': {'push_id': 4351703233,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/challenge-03',
#    'head': 'd06568a7019d07ff537bc78ae52d11983d69265d',
#    'before': 'a200d984acc20d8ac93a86b922ed2fa4ea3d07f5',
#    'commits': [{'sha': 'd06568a7019d07ff537bc78ae52d11983d69265d',
#      'author': {'email': '55067501+kucasrossy@users.noreply.github.com',
#       'name': 'kucasrossy'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kucasrossy/curso-javascript-ninja/commits/d06568a7019d07ff537bc78ae52d11983d69265d'}]},
#   'public': True,
#   'created_at': '2019-12-04T00:18:48Z'},
#  {'id': '11004964647',
#   'type': 'DeleteEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 204192453,
#    'name': 'kwokkan/card-hero',
#    'url': 'https://api.github.com/repos/kwokkan/card-hero'},
#   'payload': {'ref': 'dependabot/nuget/Microsoft.EntityFrameworkCore.Tools-3.1.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-04T00:18:48Z'},
#  {'id': '11004964642',
#   'type': 'PushEvent',
#   'actor': {'id': 5958693,
#    'login': 'yifanff',
#    'display_login': 'yifanff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yifanff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5958693?'},
#   'repo': {'id': 137703330,
#    'name': 'Aceinna/python-openimu',
#    'url': 'https://api.github.com/repos/Aceinna/python-openimu'},
#   'payload': {'push_id': 4351703229,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/bugfix',
#    'head': '3ce203c4eeede2a9f7f94a2b9483e42bdf63eeeb',
#    'before': '78877bfc3747a3adcad2bfa8c5da1a3dc89e5b25',
# ...
#       'events_url': 'https://api.github.com/users/jimmytay/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jimmytay/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 188414595,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODg0MTQ1OTU=',
#       'name': 'Web-Lab-Test',
#       'full_name': 'jimmytay/Web-Lab-Test',
#       'private': False,
#       'owner': {'login': 'jimmytay',
#        'id': 29423584,
#        'node_id': 'MDQ6VXNlcjI5NDIzNTg0',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/29423584?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jimmytay',
#        'html_url': 'https://github.com/jimmytay',
#        'followers_url': 'https://api.github.com/users/jimmytay/followers',
#        'following_url': 'https://api.github.com/users/jimmytay/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jimmytay/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jimmytay/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jimmytay/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jimmytay/orgs',
#        'repos_url': 'https://api.github.com/users/jimmytay/repos',
#        'events_url': 'https://api.github.com/users/jimmytay/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jimmytay/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jimmytay/Web-Lab-Test',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test',
#       'forks_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/forks',
#       'keys_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/teams',
#       'hooks_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/events',
#       'assignees_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/tags',
#       'blobs_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/languages',
#       'stargazers_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/subscription',
#       'commits_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/merges',
#       'archive_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/downloads',
#       'issues_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/deployments',
#       'created_at': '2019-05-24T12:01:25Z',
#       'updated_at': '2019-05-24T12:02:01Z',
#       'pushed_at': '2019-12-04T00:18:46Z',
#       'git_url': 'git://github.com/jimmytay/Web-Lab-Test.git',
#       'ssh_url': 'git@github.com:jimmytay/Web-Lab-Test.git',
#       'clone_url': 'https://github.com/jimmytay/Web-Lab-Test.git',
#       'svn_url': 'https://github.com/jimmytay/Web-Lab-Test',
#       'homepage': None,
#       'size': 792,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'PHP',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'jimmytay:master',
#      'ref': 'master',
#      'sha': '4498e753e12e9e9c2db4ed80fd4dc536811e1c50',
#      'user': {'login': 'jimmytay',
#       'id': 29423584,
#       'node_id': 'MDQ6VXNlcjI5NDIzNTg0',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/29423584?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jimmytay',
#       'html_url': 'https://github.com/jimmytay',
#       'followers_url': 'https://api.github.com/users/jimmytay/followers',
#       'following_url': 'https://api.github.com/users/jimmytay/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jimmytay/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jimmytay/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jimmytay/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jimmytay/orgs',
#       'repos_url': 'https://api.github.com/users/jimmytay/repos',
#       'events_url': 'https://api.github.com/users/jimmytay/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jimmytay/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 188414595,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODg0MTQ1OTU=',
#       'name': 'Web-Lab-Test',
#       'full_name': 'jimmytay/Web-Lab-Test',
#       'private': False,
#       'owner': {'login': 'jimmytay',
#        'id': 29423584,
#        'node_id': 'MDQ6VXNlcjI5NDIzNTg0',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/29423584?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jimmytay',
#        'html_url': 'https://github.com/jimmytay',
#        'followers_url': 'https://api.github.com/users/jimmytay/followers',
#        'following_url': 'https://api.github.com/users/jimmytay/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jimmytay/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jimmytay/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jimmytay/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jimmytay/orgs',
#        'repos_url': 'https://api.github.com/users/jimmytay/repos',
#        'events_url': 'https://api.github.com/users/jimmytay/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jimmytay/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jimmytay/Web-Lab-Test',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test',
#       'forks_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/forks',
#       'keys_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/teams',
#       'hooks_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/events',
#       'assignees_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/tags',
#       'blobs_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/languages',
#       'stargazers_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/subscription',
#       'commits_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/merges',
#       'archive_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/downloads',
#       'issues_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/deployments',
#       'created_at': '2019-05-24T12:01:25Z',
#       'updated_at': '2019-05-24T12:02:01Z',
#       'pushed_at': '2019-12-04T00:18:46Z',
#       'git_url': 'git://github.com/jimmytay/Web-Lab-Test.git',
#       'ssh_url': 'git@github.com:jimmytay/Web-Lab-Test.git',
#       'clone_url': 'https://github.com/jimmytay/Web-Lab-Test.git',
#       'svn_url': 'https://github.com/jimmytay/Web-Lab-Test',
#       'homepage': None,
#       'size': 792,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'PHP',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/pulls/2'},
#      'html': {'href': 'https://github.com/jimmytay/Web-Lab-Test/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/jimmytay/Web-Lab-Test/statuses/fab6a3d7def16af1a5af59d58cc885d135e9e134'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 18,
#     'deletions': 18,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-12-04T00:18:47Z'},
#  {'id': '11004964553',
#   'type': 'PushEvent',
#   'actor': {'id': 1121544,
#    'login': 'jessepinho',
#    'display_login': 'jessepinho',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jessepinho',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1121544?'},
#   'repo': {'id': 220719427,
#    'name': 'FrontPages/scraper',
#    'url': 'https://api.github.com/repos/FrontPages/scraper'},
#   'payload': {'push_id': 4351703181,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '794682a6eea4e3664ee0f5bb0c9fb12d108f5a3a',
#    'before': 'fb6654800e380be3b91b551473db7cbfa73aefd1',
#    'commits': [{'sha': '48741be6e8beeeccbaf3b82665df09499751880a',
#      'author': {'email': 'jesse@jessepinho.com', 'name': 'Jesse Pinho'},
#      'message': 'chore: Git-ignore .env',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/FrontPages/scraper/commits/48741be6e8beeeccbaf3b82665df09499751880a'},
#     {'sha': '794682a6eea4e3664ee0f5bb0c9fb12d108f5a3a',
#      'author': {'email': 'jesse@jessepinho.com', 'name': 'Jesse Pinho'},
#      'message': 'feat: set up deployment with Serverless',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/FrontPages/scraper/commits/794682a6eea4e3664ee0f5bb0c9fb12d108f5a3a'}]},
#   'public': True,
#   'created_at': '2019-12-04T00:18:47Z',
#   'org': {'id': 16469307,
#    'login': 'FrontPages',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/FrontPages',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16469307?'}},
#  {'id': '11004964559',
#   'type': 'CreateEvent',
#   'actor': {'id': 2956895,
#    'login': 'sahiga',
#    'display_login': 'sahiga',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sahiga',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2956895?'},
#   'repo': {'id': 175902674,
#    'name': 'sahiga/box-ui-elements',
#    'url': 'https://api.github.com/repos/sahiga/box-ui-elements'},
#   'payload': {'ref': 'storybook-stories',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Box UI Elements',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-04T00:18:47Z'}]
